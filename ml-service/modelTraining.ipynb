# %%
# -------- STEP 1: Install dependencies --------
# !pip install -q transformers datasets peft bitsandbytes accelerate sentencepiece
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 14.0 MB/s eta 0:00:00

# %%
# -------- STEP 2: Mount Google Drive (optional but recommended) --------
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://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@github.com/MHS391/LegalMate.pk.git
# Out:
# Cloning into 'LegalMate.pk'...
# remote: Enumerating objects: 1875, done.
# remote: Counting objects: 100% (1875/1875), done.
# remote: Compressing objects: 100% (1584/1584), done.
# remote: Total 1875 (delta 218), reused 1855 (delta 210), pack-reused 0 (from 0)
# Receiving objects: 100% (1875/1875), 27.73 MiB | 23.51 MiB/s, done.
# Resolving deltas: 100% (218/218), done.

# %%
# !git config --global user.email "mdharoon691@gmail.com"
# !git config --global user.name "Muhammad Haroon Shahid"

# %%
# !cd LegalMate.pk/ml-service/

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/modelTraining.ipynb ml-service/
# Out:
# cp: cannot create regular file 'ml-service/': Not a directory

# %%
# !git add .
# !git commit -m "Your commit message"
# !git push
